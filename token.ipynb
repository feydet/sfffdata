# %%
import requests # Импортируем модуль requests
token = '323348e5323348e5323348e573310ce82833233323348e55bf267444c8caf696d8fb62e' # Указываем свой сервисный токен
url = 'https://api.vk.com/method/users.get' # Указываем адрес страницы к которой делаем запрос
params = {'user_id': 1, 'v': 5.95, 'fields': 'sex,bdate', 'access_token': token, 'lang': 'ru'} # Перечисляем параметры нашего запроса в словаре params
response = requests.get(url, params=params) # Отправляем запрос
print(response.text) # Выводим текст ответа на экран
# Out:
# {"response":[{"id":1,"bdate":"10.10.1984","sex":2,"first_name":"Павел","last_name":"Дуров","can_access_closed":true,"is_closed":false}]}

# %%
from pprint import pprint # Импортируем функцию pprint()
pprint(response.json())
# Out:
# {'response': [{'bdate': '10.10.1984',
#                'can_access_closed': True,
#                'first_name': 'Павел',
#                'id': 1,
#                'is_closed': False,
#                'last_name': 'Дуров',
#                'sex': 2}]}

# %%
user = response.json()['response'][0] # Извлекаем из словаря по ключу response информацию о первом пользователе
print(user['bdate'])
# Out:
# 10.10.1984

# %%
print(user['first_name'])
# Out:
# Павел

# %%
ids = ",".join(map(str, range(1, 4))) # Формируем строку, содержащую информацию о поле id первых трёх пользователей
params = {'user_ids': ids, 'v': 5.95, 'fields': 'bday', 'access_token': token, 'lang': 'ru'} # Формируем строку параметров
pprint(requests.get(url, params=params).json()) # Посылаем запрос, полученный ответ в формате JSON-строки преобразуем в словарь и выводим на экран его содержимое, используя функцию pprint()
# Out:
# {'response': [{'can_access_closed': True,
#                'first_name': 'Павел',
#                'id': 1,
#                'is_closed': False,
#                'last_name': 'Дуров'},
#               {'can_access_closed': False,
#                'first_name': 'Александра',
#                'id': 2,
#                'is_closed': True,
#                'last_name': 'Владимирова'},
#               {'can_access_closed': True,
#                'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 3,
#                'is_closed': False,
#                'last_name': ''}]}

# %%
url = 'https://api.vk.com/method/users.get'
ids = ",".join(map(str, range(1, 501)))
params = {'user_ids': ids, 'v': 5.95, 'fields': 'sex,bdate', 'access_token': token, 'lang': 'ru'}
response = requests.get(url, params=params).json()['response']
men=women=0
for elem in response:
    if elem['sex'] == 2:
        men+=1
    elif elem['sex'] == 1:
        women+=1
    else:
        continue
print(round(women/(men+women),2))
# Out:
# 0.49

# %%
url = 'https://api.vk.com/method/groups.getMembers' # Указываем адрес обращения
params = {'group_id': 'vk', 'v': 5.95, 'access_token': token} # Формируем строку параметров
response = requests.get(url, params = params) # Посылаем запрос
data = response.json() # Ответ сохраняем в переменной data в формате словаря
print(data) # Выводим содержимое переменной data на экран (отображён фрагмент)
# Out:
# {'response': {'count': 13881495, 'items': [200000000175, 200000000200, 200000000212, 200000000214, 200000000230, 200000000252, 200000005322, 200000510128, 200000510190, 200000510246, 200000512487, 5, 6, 7, 14, 19, 34, 46, 54, 68, 88, 102, 106, 161, 163, 166, 177, 198, 212, 243, 259, 271, 279, 296, 302, 316, 319, 334, 344, 345, 353, 354, 385, 403, 404, 421, 431, 433, 450, 467, 510, 513, 550, 619, 628, 639, 640, 648, 660, 670, 690, 696, 702, 721, 741, 744, 804, 809, 832, 834, 847, 900, 905, 907, 912, 921, 943, 952, 958, 966, 976, 997, 1000, 1008, 1011, 1023, 1033, 1039, 1045, 1058, 1059, 1063, 1091, 1097, 1115, 1127, 1128, 1139, 1149, 1159, 1164, 1174, 1179, 1181, 1188, 1207, 1213, 1245, 1270, 1273, 1301, 1322, 1333, 1334, 1351, 1381, 1386, 1388, 1406, 1411, 1417, 1418, 1432, 1470, 1490, 1498, 1503, 1529, 1531, 1550, 1568, 1570, 1575, 1586, 1590, 1593, 1610, 1615, 1634, 1635, 1642, 1650, 1665, 1674, 1679, 1697, 1698, 1699, 1700, 1725, 1740, 1745, 1754, 1776, 1814, 1818, 1820, 1822, 1829, 1839, 1840, 1843, 1852, 1858, 1863, 1869, 1887, 1889, 1902, 1917, 1925, 1936, 1941, 1943, 1947, 1955, 1969, 1989, 2022, 2028, 2030, 2042, 2050, 2051, 2052, 2059, 2064, 2067, 2069, 2077, 2103, 2152, 2195, 2201, 2222, 2236, 2281, 2296, 2298, 2306, 2375, 2376, 2389, 2395, 2403, 2413, 2444, 2456, 2466, 2470, 2481, 2491, 2498, 2515, 2523, 2534, 2538, 2593, 2601, 2617, 2622, 2629, 2636, 2644, 2654, 2663, 2676, 2703, 2706, 2745, 2755, 2761, 2767, 2787, 2788, 2797, 2813, 2827, 2835, 2858, 2860, 2894, 2908, 2909, 2919, 2922, 2932, 2943, 2953, 2962, 2969, 2982, 3001, 3002, 3041, 3130, 3135, 3139, 3153, 3159, 3162, 3172, 3176, 3186, 3196, 3231, 3250, 3254, 3290, 3321, 3328, 3331, 3332, 3357, 3364, 3372, 3373, 3383, 3384, 3388, 3420, 3422, 3427, 3431, 3436, 3438, 3441, 3450, 3451, 3458, 3472, 3491, 3492, 3520, 3545, 3554, 3556, 3581, 3591, 3593, 3626, 3637, 3646, 3653, 3657, 3658, 3675, 3684, 3690, 3693, 3697, 3719, 3770, 3775, 3786, 3820, 3824, 3836, 3837, 3841, 3856, 3863, 3872, 3894, 3897, 3900, 3904, 3909, 3938, 3948, 3960, 3979, 3997, 4004, 4023, 4041, 4048, 4104, 4108, 4130, 4157, 4169, 4188, 4189, 4192, 4196, 4213, 4223, 4234, 4236, 4262, 4265, 4282, 4338, 4364, 4394, 4439, 4440, 4447, 4449, 4485, 4492, 4505, 4513, 4516, 4521, 4530, 4537, 4543, 4554, 4558, 4563, 4564, 4583, 4599, 4601, 4603, 4617, 4622, 4640, 4668, 4670, 4672, 4680, 4689, 4731, 4741, 4748, 4751, 4754, 4755, 4769, 4770, 4818, 4825, 4828, 4837, 4841, 4846, 4849, 4857, 4862, 4866, 4881, 4901, 4913, 4918, 4921, 4923, 4927, 4928, 4947, 4972, 4975, 4981, 4984, 5002, 5011, 5017, 5073, 5102, 5106, 5127, 5129, 5161, 5163, 5183, 5226, 5262, 5273, 5276, 5280, 5286, 5354, 5385, 5386, 5387, 5392, 5394, 5399, 5401, 5430, 5432, 5438, 5471, 5472, 5474, 5484, 5527, 5547, 5566, 5590, 5597, 5606, 5615, 5629, 5634, 5649, 5683, 5690, 5701, 5746, 5752, 5768, 5793, 5803, 5819, 5837, 5846, 5850, 5866, 5875, 5876, 5896, 5914, 5923, 5944, 5959, 5965, 5971, 5990, 5991, 5993, 5997, 6002, 6037, 6078, 6086, 6099, 6107, 6111, 6125, 6136, 6154, 6155, 6161, 6167, 6181, 6183, 6186, 6187, 6199, 6203, 6240, 6260, 6265, 6323, 6333, 6339, 6379, 6380, 6383, 6390, 6393, 6400, 6467, 6492, 6499, 6520, 6547, 6557, 6564, 6595, 6615, 6627, 6635, 6670, 6689, 6703, 6715, 6740, 6758, 6775, 6797, 6801, 6807, 6851, 6855, 6862, 6894, 6903, 6906, 6908, 6950, 6953, 6954, 6960, 6986, 6994, 7006, 7047, 7050, 7052, 7068, 7087, 7091, 7099, 7112, 7115, 7117, 7126, 7141, 7180, 7188, 7200, 7226, 7256, 7262, 7275, 7290, 7323, 7334, 7338, 7347, 7360, 7391, 7402, 7404, 7428, 7451, 7473, 7481, 7488, 7492, 7500, 7517, 7525, 7542, 7550, 7557, 7581, 7595, 7615, 7628, 7639, 7652, 7666, 7692, 7700, 7725, 7737, 7755, 7768, 7777, 7799, 7801, 7822, 7830, 7847, 7855, 7858, 7860, 7862, 7882, 7897, 7996, 7998, 8019, 8022, 8069, 8070, 8080, 8093, 8114, 8131, 8140, 8149, 8151, 8156, 8166, 8167, 8168, 8181, 8182, 8201, 8224, 8266, 8273, 8297, 8298, 8310, 8321, 8331, 8347, 8348, 8363, 8373, 8377, 8408, 8418, 8436, 8443, 8481, 8484, 8495, 8505, 8518, 8536, 8561, ...

# %%
print(len(data['response']['items']))
# Out:
# 1000

# %%
users_for_checking = data['response']['items'][:20] # Загружаем в переменную информацию об id первых 20 пользователей в виде списка
print(users_for_checking) # Выводим перечень id первых 20 пользователей
# Out:
# [200000000175, 200000000200, 200000000212, 200000000214, 200000000230, 200000000252, 200000005322, 200000510128, 200000510190, 200000510246, 200000512487, 5, 6, 7, 14, 19, 34, 46, 54, 68]

# %%
url = 'https://api.vk.com/method/groups.getMembers' # Указываем адрес обращения
count = 5 
offset = 0 
user_ids = [] 
max_count = 20 
while offset < max_count: 
    # Будем выгружать по count=5 пользователей, 
    # начиная с того места, где закончили на предыдущей итерации (offset) 
    print('Выгружаю {} пользователей с offset = {}'.format(count, offset))   
    params = {'group_id': 'vk', 'v': 5.95, 'count': count, 'offset': offset, 'access_token': token} 
    response = requests.get(url, params = params) 
    data = response.json() 
    user_ids += data['response']['items'] 
    # Увеличиваем смещение на количество строк, которое мы уже выгрузили 
    offset += count 
print(user_ids)
# Out:
# Выгружаю 5 пользователей с offset = 0
# Выгружаю 5 пользователей с offset = 5
# Выгружаю 5 пользователей с offset = 10
# Выгружаю 5 пользователей с offset = 15
# [200000000175, 200000000200, 200000000212, 200000000214, 200000000230, 200000000252, 200000005322, 200000510128, 200000510190, 200000510246, 200000512487, 5, 6, 7, 14, 19, 34, 46, 54, 68]

# %%
print(user_ids == users_for_checking)
# Out:
# True

# %%
import time
url = 'https://api.vk.com/method/groups.getMembers' # Указываем адрес страницы, к которой делаем запрос
count = 1000 
offset = 0  
user_ids = []  
while offset < 5000: 
    params = {'group_id': 'vk', 'v': 5.95, 'count': count, 'offset': offset, 'access_token': token} 
    response = requests.get(url, params = params) 
    data = response.json() 
    user_ids += data['response']['items'] 
    offset += count 
    print('Ожидаю 0.5 секунды...') 
    time.sleep(0.5) 
print('Цикл завершен, offset =',offset)
# Out:
# Ожидаю 0.5 секунды...
# Ожидаю 0.5 секунды...
# Ожидаю 0.5 секунды...
# Ожидаю 0.5 секунды...
# Ожидаю 0.5 секунды...
# Цикл завершен, offset = 5000

# %%
from pprint import pprint
url = 'https://api.vk.com/method/wall.get' # Указываем адрес страницы, к которой делаем запрос
params = {'domain': 'vk', 'filter': 'owner', 'count': 1000, 'offset': 0, 'access_token': token, 'v': 5.95} 
response = requests.get(url, params = params) 
pprint(response.json())
# Out:
# {'response': {'count': 986,
#               'items': [{'attachments': [{'photo': {'access_key': 'a1b7a13843a5620789',
#                                                     'album_id': -7,
#                                                     'date': 1774023698,
#                                                     'id': 457371117,
#                                                     'orig_photo': {'height': 1920,
#                                                                    'type': 'base',
#                                                                    'url': 'https://sun1-54.userapi.com/s/v1/ig2/Z9b4pzgoele2U5UsN2lxRTtMdsjMF2afTQLiQ5sJdn8WcrHFcXWuP7zbd3Mjw5HOwRRu27RpfhTMVZmh6LdKUKUH.jpg?quality=95&crop=0,0,1920,1920&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,1920x1920&from=bu',
#                                                                    'width': 1920},
#                                                     'owner_id': -22822305,
#                                                     'post_id': 1669213,
#                                                     'sizes': [{'height': 72,
#                                                                'type': 's',
#                                                                'url': 'https://sun1-54.userapi.com/s/v1/ig2/Z9b4pzgoele2U5UsN2lxRTtMdsjMF2afTQLiQ5sJdn8WcrHFcXWuP7zbd3Mjw5HOwRRu27RpfhTMVZmh6LdKUKUH.jpg?quality=95&crop=0,0,1920,1920&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,1920x1920&from=bu&cs=72x0',
#                                                                'width': 72},
#                                                               {'height': 160,
#                                                                'type': 'm',
#                                                                'url': 'https://sun1-54.userapi.com/s/v1/ig2/Z9b4pzgoele2U5UsN2lxRTtMdsjMF2afTQLiQ5sJdn8WcrHFcXWuP7zbd3Mjw5HOwRRu27RpfhTMVZmh6LdKUKUH.jpg?quality=95&crop=0,0,1920,1920&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,1920x1920&from=bu&cs=160x0',
#                                                                'width': 160},
#                                                               {'height': 640,
#                                                                'type': 'x',
#                                                                'url': 'https://sun1-54.userapi.com/s/v1/ig2/Z9b4pzgoele2U5UsN2lxRTtMdsjMF2afTQLiQ5sJdn8WcrHFcXWuP7zbd3Mjw5HOwRRu27RpfhTMVZmh6LdKUKUH.jpg?quality=95&crop=0,0,1920,1920&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,1920x1920&from=bu&cs=640x0',
#                                                                'width': 640},
#                                                               {'height': 1080,
#                                                                'type': 'y',
#                                                                'url': 'https://sun1-54.userapi.com/s/v1/ig2/Z9b4pzgoele2U5UsN2lxRTtMdsjMF2afTQLiQ5sJdn8WcrHFcXWuP7zbd3Mjw5HOwRRu27RpfhTMVZmh6LdKUKUH.jpg?quality=95&crop=0,0,1920,1920&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,1920x1920&from=bu&cs=1080x0',
#                                                                'width': 1080},
#                                                               {'height': 1280,
#                                                                'type': 'z',
#                                                                'url': 'https://sun1-54.userapi.com/s/v1/ig2/Z9b4pzgoele2U5UsN2lxRTtMdsjMF2afTQLiQ5sJdn8WcrHFcXWuP7zbd3Mjw5HOwRRu27RpfhTMVZmh6LdKUKUH.jpg?quality=95&crop=0,0,1920,1920&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,1920x1920&from=bu&cs=1280x0',
#                                                                'width': 1280},
#                                                               {'height': 1920,
#                                                                'type': 'w',
#                                                                'url': 'https://sun1-54.userapi.com/s/v1/ig2/Z9b4pzgoele2U5UsN2lxRTtMdsjMF2afTQLiQ5sJdn8WcrHFcXWuP7zbd3Mjw5HOwRRu27RpfhTMVZmh6LdKUKUH.jpg?quality=95&crop=0,0,1920,1920&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,1920x1920&from=bu&cs=1920x0',
#                                                                'width': 1920},
#                                                               {'height': 108,
#                                                                'type': 'o',
#                                                                'url': 'https://sun1-54.userapi.com/s/v1/ig2/Z9b4pzgoele2U5UsN2lxRTtMdsjMF2afTQLiQ5sJdn8WcrHFcXWuP7zbd3Mjw5HOwRRu27RpfhTMVZmh6LdKUKUH.jpg?quality=95&crop=0,0,1920,1920&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,1920x1920&from=bu&cs=108x0',
#                                                                'width': 108},
#                                                               {'height': 240,
#                                                                'type': 'p',
#                                                                'url': 'https://sun1-54.userapi.com/s/v1/ig2/Z9b4pzgoele2U5UsN2lxRTtMdsjMF2afTQLiQ5sJdn8WcrHFcXWuP7zbd3Mjw5HOwRRu27RpfhTMVZmh6LdKUKUH.jpg?quality=95&crop=0,0,1920,1920&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,1920x1920&from=bu&cs=240x0',
#                                                                'width': 240},
#                                                               {'height': 360,
#                                                                'type': 'q',
#                                                                'url': 'https://sun1-54.userapi.com/s/v1/ig2/Z9b4pzgoele2U5UsN2lxRTtMdsjMF2afTQLiQ5sJdn8WcrHFcXWuP7zbd3Mjw5HOwRRu27RpfhTMVZmh6LdKUKUH.jpg?quality=95&crop=0,0,1920,1920&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,1920x1920&from=bu&cs=360x0',
#                                                                'width': 360},
#                                                               {'height': 540,
#                                                                'type': 'r',
#                                                                'url': 'https://sun1-54.userapi.com/s/v1/ig2/Z9b4pzgoele2U5UsN2lxRTtMdsjMF2afTQLiQ5sJdn8WcrHFcXWuP7zbd3Mjw5HOwRRu27RpfhTMVZmh6LdKUKUH.jpg?quality=95&crop=0,0,1920,1920&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,1920x1920&from=bu&cs=540x0',
#                                                                'width': 540},
#                                                               {'height': 1920,
#                                                                'type': 'base',
#                                                                'url': 'https://sun1-54.userapi.com/s/v1/ig2/Z9b4pzgoele2U5UsN2lxRTtMdsjMF2afTQLiQ5sJdn8WcrHFcXWuP7zbd3Mjw5HOwRRu27RpfhTMVZmh6LdKUKUH.jpg?quality=95&crop=0,0,1920,1920&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,1920x1920&from=bu',
#                                                                'width': 1920}],
#                                                     'text': '',
#                                                     'user_id': 100,
#                                                     'web_view_token': 'e9b825b5e1383c9098'},
#                                           'type': 'photo'}],
#                          'comments': {'count': 292},
#                          'date': 1774081260,
#                          'from_id': -22822305,
#                          'hash': 'bG9bWjsupbfFYvNgYw',
#                          'id': 1669315,
#                          'inner_type': 'wall_wallpost',
#                          'likes': {'can_like': 0,
#                                    'count': 188,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_type': 'post',
#                          'push_subscription': {'is_subscribed': False},
#                          'reposts': {'count': 22},
#                          'text': 'Играем! Угадаете персонажа по vmoji? Ждём '
#                                  'ваши варианты в комментариях! И кидайте '
#                                  'своих персонажей — заценим образы 💫\n'
#                                  '\n'
#                                  'А в мемном наборе вас ждут два новых '
#                                  'стикера: vk.com/stickers/vmoji_meme',
#                          'type': 'post',
#                          'views': {'count': 83274}},
#                         {'attachments': [{'photo': {'access_key': '4de6b6a4e1fc99706a',
#                                                     'album_id': -7,
#                                                     'date': 1773852720,
#                                                     'id': 457371060,
#                                                     'orig_photo': {'height': 1920,
#                                                                    'type': 'base',
#                                                                    'url': 'https://sun1-89.userapi.com/s/v1/ig2/RchOsUUZw88qYXDu0hxq7BuhD80I-HqiU7b6chaqdDs3jfPeSx82FquO1x5fG22D2573J6CaGlhD_SI0o-eyOq3J.jpg?quality=95&crop=0,0,1920,1920&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,1920x1920&from=bu',
#                                                                    'width': 1920},
#                                                     'owner_id': -22822305,
#                                                     'post_id': 1668717,
#                                                     'sizes': [{'height': 72,
#                                                                'type': 's',
#                                                                'url': 'https://sun1-89.userapi.com/s/v1/ig2/RchOsUUZw88qYXDu0hxq7BuhD80I-HqiU7b6chaqdDs3jfPeSx82FquO1x5fG22D2573J6CaGlhD_SI0o-eyOq3J.jpg?quality=95&crop=0,0,1920,1920&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,1920x1920&from=bu&cs=72x0',
#                                                                'width': 72},
#                                                               {'height': 160,
#                                                                'type': 'm',
#                                                                'url': 'https://sun1-89.userapi.com/s/v1/ig2/RchOsUUZw88qYXDu0hxq7BuhD80I-HqiU7b6chaqdDs3jfPeSx82FquO1x5fG22D2573J6CaGlhD_SI0o-eyOq3J.jpg?quality=95&crop=0,0,1920,1920&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,1920x1920&from=bu&cs=160x0',
#                                                                'width': 160},
#                                                               {'height': 640,
#                                                                'type': 'x',
#                                                                'url': 'https://sun1-89.userapi.com/s/v1/ig2/RchOsUUZw88qYXDu0hxq7BuhD80I-HqiU7b6chaqdDs3jfPeSx82FquO1x5fG22D2573J6CaGlhD_SI0o-eyOq3J.jpg?quality=95&crop=0,0,1920,1920&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,1920x1920&from=bu&cs=640x0',
#                                                                'width': 640},
#                                                               {'height': 1080,
#                                                                'type': 'y',
#                                                                'url': 'https://sun1-89.userapi.com/s/v1/ig2/RchOsUUZw88qYXDu0hxq7BuhD80I-HqiU7b6chaqdDs3jfPeSx82FquO1x5fG22D2573J6CaGlhD_SI0o-eyOq3J.jpg?quality=95&crop=0,0,1920,1920&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,1920x1920&from=bu&cs=1080x0',
#                                                                'width': 1080},
#                                                               {'height': 1280,
#                                                                'type': 'z',
#                                                                'url': 'https://sun1-89.userapi.com/s/v1/ig2/RchOsUUZw88qYXDu0hxq7BuhD80I-HqiU7b6chaqdDs3jfPeSx82FquO1x5fG22D2573J6CaGlhD_SI0o-eyOq3J.jpg?quality=95&crop=0,0,1920,1920&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,1920x1920&from=bu&cs=1280x0',
#                                                                'width': 1280},
#                                                               {'height': 1920,
#                                                                'type': 'w',
#                                                                'url': 'https://sun1-89.userapi.com/s/v1/ig2/RchOsUUZw88qYXDu0hxq7BuhD80I-HqiU7b6chaqdDs3jfPeSx82FquO1x5fG22D2573J6CaGlhD_SI0o-eyOq3J.jpg?quality=95&crop=0,0,1920,1920&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,1920x1920&from=bu&cs=1920x0',
#                                                                'width': 1920},
#                                                               {'height': 108,
#                                                                'type': 'o',
#                                                                'url': 'https://sun1-89.userapi.com/s/v1/ig2/RchOsUUZw88qYXDu0hxq7BuhD80I-HqiU7b6chaqdDs3jfPeSx82FquO1x5fG22D2573J6CaGlhD_SI0o-eyOq3J.jpg?quality=95&crop=0,0,1920,1920&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,1920x1920&from=bu&cs=108x0',
#                                                                'width': 108},
#                                                               {'height': 240,
#                                                                'type': 'p',
#                                                                'url': 'https://sun1-89.userapi.com/s/v1/ig2/RchOsUUZw88qYXDu0hxq7BuhD80I-HqiU7b6chaqdDs3jfPeSx82FquO1x5fG22D2573J6CaGlhD_SI0o-eyOq3J.jpg?quality=95&crop=0,0,1920,1920&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,1920x1920&from=bu&cs=240x0',
#                                                                'width': 240},
#                                                               {'height': 360,
#                                                                'type': 'q',
#                                                                'url': 'https://sun1-89.userapi.com/s/v1/ig2/RchOsUUZw88qYXDu0hxq7BuhD80I-HqiU7b6chaqdDs3jfPeSx82FquO1x5fG22D2573J6CaGlhD_SI0o-eyOq3J.jpg?quality=95&crop=0,0,1920,1920&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,1920x1920&from=bu&cs=360x0',
#                                                                'width': 360},
#                                                               {'height': 540,
#                                                                'type': 'r',
#                                                                'url': 'https://sun1-89.userapi.com/s/v1/ig2/RchOsUUZw88qYXDu0hxq7BuhD80I-HqiU7b6chaqdDs3jfPeSx82FquO1x5fG22D2573J6CaGlhD_SI0o-eyOq3J.jpg?quality=95&crop=0,0,1920,1920&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,1920x1920&from=bu&cs=540x0',
#                                                                'width': 540},
#                                                               {'height': 1920,
#                                                                'type': 'base',
#                                                                'url': 'https://sun1-89.userapi.com/s/v1/ig2/RchOsUUZw88qYXDu0hxq7BuhD80I-HqiU7b6chaqdDs3jfPeSx82FquO1x5fG22D2573J6CaGlhD_SI0o-eyOq3J.jpg?quality=95&crop=0,0,1920,1920&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,1920x1920&from=bu',
#                                                                'width': 1920}],
#                                                     'text': '',
#                                                     'user_id': 100,
#                                                     'web_view_token': '6db1e78b8512bf400c'},
#                                           'type': 'photo'}],
#                          'comments': {'count': 416},
#                          'date': 1773906688,
#                          'from_id': -22822305,
#                          'hash': 'RhG8gJLG24ilHrJIew',
#                          'id': 1668806,
#                          'inner_type': 'wall_wallpost',
#                          'likes': {'can_like': 0,
#                                    'count': 447,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_type': 'post',
#                          'push_subscription': {'is_subscribed': False},
#                          'reposts': {'count': 98},
#                          'text': '💙 Синее сердечко нельзя использовать в '
#                                  'таргетированной рекламе ВКонтакте. Откуда вы '
#                                  'это узнали бы (кроме нашего поста)? \n'
#                                  '\n'
#                                  'Информацию можно искать долго, а таргетолог '
#                                  'уже всё знает. Кстати, в новой акции VK '
#                                  'Реклама закрепит специалиста за вами на 3 '
#                                  'месяца — а он и рекламную кампанию соберёт, '
#                                  'и аудитории выберет, и нужные эмодзи '
#                                  'поставит. А заодно сможете получить до '
#                                  '25\u202f000 рублей бонусами. \n'
#                                  '\n'
#                                  'Чтобы участвовать, зарегистрируйтесь по '
#                                  'ссылке и пополните баланс в VK Рекламе до 29 '
#                                  'марта. \n'
#                                  'Проверяйте: vk.cc/cVpyoX',
#                          'type': 'post',
#                          'views': {'count': 503549}},
#                         {'attachments': [{'photo': {'access_key': '5410cf2924a0677aae',
#                                                     'album_id': -7,
#                                                     'date': 1773844191,
#                                                     'id': 457371055,
#                                                     'orig_photo': {'height': 1920,
#                                                                    'type': 'base',
#                                                                    'url': 'https://sun1-85.userapi.com/s/v1/ig2/x6_Eq_CII4P3_pmTSfknYainEVcdyW9W3-czVJhNieBb3CvTnadIXnC9t0uN0IUEq-gwStS8BARSe7mRhkuRt0pE.jpg?quality=95&crop=0,0,1920,1920&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,1920x1920&from=bu',
#                                                                    'width': 1920},
#                                                     'owner_id': -22822305,
#                                                     'post_id': 1668659,
#                                                     'sizes': [{'height': 72,
#                                                                'type': 's',
#                                                                'url': 'https://sun1-85.userapi.com/s/v1/ig2/x6_Eq_CII4P3_pmTSfknYainEVcdyW9W3-czVJhNieBb3CvTnadIXnC9t0uN0IUEq-gwStS8BARSe7mRhkuRt0pE.jpg?quality=95&crop=0,0,1920,1920&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,1920x1920&from=bu&cs=72x0',
#                                                                'width': 72},
#                                                               {'height': 160,
#                                                                'type': 'm',
#                                                                'url': 'https://sun1-85.userapi.com/s/v1/ig2/x6_Eq_CII4P3_pmTSfknYainEVcdyW9W3-czVJhNieBb3CvTnadIXnC9t0uN0IUEq-gwStS8BARSe7mRhkuRt0pE.jpg?quality=95&crop=0,0,1920,1920&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,1920x1920&from=bu&cs=160x0',
#                                                                'width': 160},
#                                                               {'height': 640,
#                                                                'type': 'x',
#                                                                'url': 'https://sun1-85.userapi.com/s/v1/ig2/x6_Eq_CII4P3_pmTSfknYainEVcdyW9W3-czVJhNieBb3CvTnadIXnC9t0uN0IUEq-gwStS8BARSe7mRhkuRt0pE.jpg?quality=95&crop=0,0,1920,1920&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,1920x1920&from=bu&cs=640x0',
#                                                                'width': 640},
#                                                               {'height': 1080,
#                                                                'type': 'y',
#                                                                'url': 'https://sun1-85.userapi.com/s/v1/ig2/x6_Eq_CII4P3_pmTSfknYainEVcdyW9W3-czVJhNieBb3CvTnadIXnC9t0uN0IUEq-gwStS8BARSe7mRhkuRt0pE.jpg?quality=95&crop=0,0,1920,1920&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,1920x1920&from=bu&cs=1080x0',
#                                                                'width': 1080},
#                                                               {'height': 1280,
#                                                                'type': 'z',
#                                                                'url': 'https://sun1-85.userapi.com/s/v1/ig2/x6_Eq_CII4P3_pmTSfknYainEVcdyW9W3-czVJhNieBb3CvTnadIXnC9t0uN0IUEq-gwStS8BARSe7mRhkuRt0pE.jpg?quality=95&crop=0,0,1920,1920&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,1920x1920&from=bu&cs=1280x0',
#                                                                'width': 1280},
#                                                               {'height': 1920,
#                                                                'type': 'w',
#                                                                'url': 'https://sun1-85.userapi.com/s/v1/ig2/x6_Eq_CII4P3_pmTSfknYainEVcdyW9W3-czVJhNieBb3CvTnadIXnC9t0uN0IUEq-gwStS8BARSe7mRhkuRt0pE.jpg?quality=95&crop=0,0,1920,1920&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,1920x1920&from=bu&cs=1920x0',
#                                                                'width': 1920},
#                                                               {'height': 108,
#                                                                'type': 'o',
#                                                                'url': 'https://sun1-85.userapi.com/s/v1/ig2/x6_Eq_CII4P3_pmTSfknYainEVcdyW9W3-czVJhNieBb3CvTnadIXnC9t0uN0IUEq-gwStS8BARSe7mRhkuRt0pE.jpg?quality=95&crop=0,0,1920,1920&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,1920x1920&from=bu&cs=108x0',
#                                                                'width': 108},
#                                                               {'height': 240,
#                                                                'type': 'p',
#                                                                'url': 'https://sun1-85.userapi.com/s/v1/ig2/x6_Eq_CII4P3_pmTSfknYainEVcdyW9W3-czVJhNieBb3CvTnadIXnC9t0uN0IUEq-gwStS8BARSe7mRhkuRt0pE.jpg?quality=95&crop=0,0,1920,1920&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,1920x1920&from=bu&cs=240x0',
#                                                                'width': 240},
#                                                               {'height': 360,
#                                                                'type': 'q',
#                                                                'url': 'https://sun1-85.userapi.com/s/v1/ig2/x6_Eq_CII4P3_pmTSfknYainEVcdyW9W3-czVJhNieBb3CvTnadIXnC9t0uN0IUEq-gwStS8BARSe7mRhkuRt0pE.jpg?quality=95&crop=0,0,1920,1920&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,1920x1920&from=bu&cs=360x0',
#                                                                'width': 360},
#                                                               {'height': 540,
#                                                                'type': 'r',
#                                                                'url': 'https://sun1-85.userapi.com/s/v1/ig2/x6_Eq_CII4P3_pmTSfknYainEVcdyW9W3-czVJhNieBb3CvTnadIXnC9t0uN0IUEq-gwStS8BARSe7mRhkuRt0pE.jpg?quality=95&crop=0,0,1920,1920&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,1920x1920&from=bu&cs=540x0',
#                                                                'width': 540},
#                                                               {'height': 1920,
#                                                                'type': 'base',
#                                                                'url': 'https://sun1-85.userapi.com/s/v1/ig2/x6_Eq_CII4P3_pmTSfknYainEVcdyW9W3-czVJhNieBb3CvTnadIXnC9t0uN0IUEq-gwStS8BARSe7mRhkuRt0pE.jpg?quality=95&crop=0,0,1920,1920&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,1920x1920&from=bu',
#                                                                'width': 1920}],
#                                                     'text': '',
#                                                     'user_id': 100,
#                                                     'web_view_token': '3b61e55299a925a0af'},
#                                           'type': 'photo'}],
#                          'comments': {'count': 125},
#                          'date': 1773846032,
#                          'from_id': -22822305,
#                          'hash': 'f6WeCFEvA6lzldbCnQ',
#                          'id': 1668672,
#                          'inner_type': 'wall_wallpost',
#                          'likes': {'can_like': 0,
#                                    'count': 751,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_type': 'post',
#                          'push_subscription': {'is_subscribed': False},
#                          'reposts': {'count': 85},
#                          'text': 'Если вы ещё не знакомы, знакомьтесь: это '
#                                  'Крис и Кристина — стикеры с ними стали '
#                                  'самыми популярными под '
#                                  '[https://vk.com/wall-22822305_1667676|этим '
#                                  'постом] 😍\n'
#                                  '\n'
#                                  '• Крис — крупный и уверенный в себе крыс\n'
#                                  '• Кристина — компетентна в сфере сплетен, '
#                                  'опытна во всяческих инсинуациях и крыса по '
#                                  'натуре\n'
#                                  '\n'
#                                  'Вместе они приятная парочка, которую Варвара '
#                                  'Максименкова нарисовала в стикерах. '
#                                  'Запускайте ребят в свои чаты: '
#                                  'vk.com/stickers/chrisandkristina',
#                          'type': 'post',
#                          'views': {'count': 204691}},
#                         {'attachments': [{'photo': {'access_key': '53331bd2071f78b215',
#                                                     'album_id': -7,
#                                                     'date': 1773667444,
#                                                     'id': 457371002,
#                                                     'orig_photo': {'height': 1920,
#                                                                    'type': 'base',
#                                                                    'url': 'https://sun1-88.userapi.com/s/v1/ig2/3AoP2y28oOMT2S152U04r-x6wtgvq39Mx625KwLuAnwbDXHKZ15CuGCrhk-fam4-V8yb_WABVdnkaLfqlRFxtiU8.jpg?quality=95&crop=0,0,1920,1920&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,1920x1920&from=bu',
#                                                                    'width': 1920},
#                                                     'owner_id': -22822305,
#                                                     'post_id': 1668201,
#                                                     'sizes': [{'height': 72,
#                                                                'type': 's',
#                                                                'url': 'https://sun1-88.userapi.com/s/v1/ig2/3AoP2y28oOMT2S152U04r-x6wtgvq39Mx625KwLuAnwbDXHKZ15CuGCrhk-fam4-V8yb_WABVdnkaLfqlRFxtiU8.jpg?quality=95&crop=0,0,1920,1920&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,1920x1920&from=bu&cs=72x0',
#                                                                'width': 72},
#                                                               {'height': 160,
#                                                                'type': 'm',
#                                                                'url': 'https://sun1-88.userapi.com/s/v1/ig2/3AoP2y28oOMT2S152U04r-x6wtgvq39Mx625KwLuAnwbDXHKZ15CuGCrhk-fam4-V8yb_WABVdnkaLfqlRFxtiU8.jpg?quality=95&crop=0,0,1920,1920&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,1920x1920&from=bu&cs=160x0',
#                                                                'width': 160},
#                                                               {'height': 640,
#                                                                'type': 'x',
#                                                                'url': 'https://sun1-88.userapi.com/s/v1/ig2/3AoP2y28oOMT2S152U04r-x6wtgvq39Mx625KwLuAnwbDXHKZ15CuGCrhk-fam4-V8yb_WABVdnkaLfqlRFxtiU8.jpg?quality=95&crop=0,0,1920,1920&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,1920x1920&from=bu&cs=640x0',
#                                                                'width': 640},
#                                                               {'height': 1080,
#                                                                'type': 'y',
#                                                                'url': 'https://sun1-88.userapi.com/s/v1/ig2/3AoP2y28oOMT2S152U04r-x6wtgvq39Mx625KwLuAnwbDXHKZ15CuGCrhk-fam4-V8yb_WABVdnkaLfqlRFxtiU8.jpg?quality=95&crop=0,0,1920,1920&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,1920x1920&from=bu&cs=1080x0',
#                                                                'width': 1080},
#                                                               {'height': 1280,
#                                                                'type': 'z',
#                                                                'url': 'https://sun1-88.userapi.com/s/v1/ig2/3AoP2y28oOMT2S152U04r-x6wtgvq39Mx625KwLuAnwbDXHKZ15CuGCrhk-fam4-V8yb_WABVdnkaLfqlRFxtiU8.jpg?quality=95&crop=0,0,1920,1920&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,1920x1920&from=bu&cs=1280x0',
#                                                                'width': 1280},
#                                                               {'height': 1920,
#                                                                'type': 'w',
#                                                                'url': 'https://sun1-88.userapi.com/s/v1/ig2/3AoP2y28oOMT2S152U04r-x6wtgvq39Mx625KwLuAnwbDXHKZ15CuGCrhk-fam4-V8yb_WABVdnkaLfqlRFxtiU8.jpg?quality=95&crop=0,0,1920,1920&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,1920x1920&from=bu&cs=1920x0',
#                                                                'width': 1920},
#                                                               {'height': 108,
#                                                                'type': 'o',
#                                                                'url': 'https://sun1-88.userapi.com/s/v1/ig2/3AoP2y28oOMT2S152U04r-x6wtgvq39Mx625KwLuAnwbDXHKZ15CuGCrhk-fam4-V8yb_WABVdnkaLfqlRFxtiU8.jpg?quality=95&crop=0,0,1920,1920&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,1920x1920&from=bu&cs=108x0',
#                                                                'width': 108},
#                                                               {'height': 240,
#                                                                'type': 'p',
#                                                                'url': 'https://sun1-88.userapi.com/s/v1/ig2/3AoP2y28oOMT2S152U04r-x6wtgvq39Mx625KwLuAnwbDXHKZ15CuGCrhk-fam4-V8yb_WABVdnkaLfqlRFxtiU8.jpg?quality=95&crop=0,0,1920,1920&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,1920x1920&from=bu&cs=240x0',
#                                                                'width': 240},
#                                                               {'height': 360,
#                                                                'type': 'q',
#                                                                'url': 'https://sun1-88.userapi.com/s/v1/ig2/3AoP2y28oOMT2S152U04r-x6wtgvq39Mx625KwLuAnwbDXHKZ15CuGCrhk-fam4-V8yb_WABVdnkaLfqlRFxtiU8.jpg?quality=95&crop=0,0,1920,1920&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,1920x1920&from=bu&cs=360x0',
#                                                                'width': 360},
#                                                               {'height': 540,
#                                                                'type': 'r',
#                                                                'url': 'https://sun1-88.userapi.com/s/v1/ig2/3AoP2y28oOMT2S152U04r-x6wtgvq39Mx625KwLuAnwbDXHKZ15CuGCrhk-fam4-V8yb_WABVdnkaLfqlRFxtiU8.jpg?quality=95&crop=0,0,1920,1920&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,1920x1920&from=bu&cs=540x0',
#                                                                'width': 540},
#                                                               {'height': 1920,
#                                                                'type': 'base',
#                                                                'url': 'https://sun1-88.userapi.com/s/v1/ig2/3AoP2y28oOMT2S152U04r-x6wtgvq39Mx625KwLuAnwbDXHKZ15CuGCrhk-fam4-V8yb_WABVdnkaLfqlRFxtiU8.jpg?quality=95&crop=0,0,1920,1920&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,1920x1920&from=bu',
#                                                                'width': 1920}],
#                                                     'text': '',
#                                                     'user_id': 100,
#                                                     'web_view_token': '919ba87fd44ecda4b3'},
#                                           'type': 'photo'}],
#                          'comments': {'count': 322},
#                          'date': 1773667444,
#                          'from_id': -22822305,
#                          'hash': '0EHgiJglXTpu3h29Tg',
#                          'id': 1668201,
#                          'inner_type': 'wall_wallpost',
#                          'likes': {'can_like': 0,
#                                    'count': 273,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_type': 'post',
#                          'push_subscription': {'is_subscribed': False},
#                          'reposts': {'count': 62},
#                          'text': 'Если партнёр досмотрит сериал без вас — это '
#                                  'можно считать «сериальной изменой»? Команда '
#                                  'VK Видео узнала, как пары смотрят сериалы.\n'
#                                  '\n'
#                                  'Ловите результаты ⚡\n'
#                                  '• 40% зрителей хотя бы раз досматривали '
#                                  'сериал втайне от партнёра\n'
#                                  '• 23% считают это настоящей «сериальной '
#                                  'изменой»\n'
#                                  '• 30% всегда смотрят сериалы только вместе\n'
#                                  '\n'
#                                  'А ещё 64% опрошенных уверены: совместный '
#                                  'просмотр укрепляет отношения. При этом '
#                                  'конфликты из-за сериалов возникают всего у '
#                                  '8% пар.\n'
#                                  '\n'
#                                  'Почему люди идут на «преступление»?\n'
#                                  '• 40% ответили, что партнёру не нравится '
#                                  'сериал\n'
#                                  '• 35%, что у второй половинки нет времени\n'
#                                  '• 20% просто не могут сдержаться\n'
#                                  '\n'
#                                  'А вы досматриваете без партнёра или '
#                                  'терпеливо ждёте? Делитесь в комментариях 👇',
#                          'type': 'post',
#                          'views': {'count': 148160}},
#                         {'attachments': [{'photo': {'access_key': '81ab9caab67ee493c5',
#                                                     'album_id': -7,
#                                                     'date': 1773415632,
#                                                     'id': 457370952,
#                                                     'orig_photo': {'height': 1920,
#                                                                    'type': 'base',
#                                                                    'url': 'https://sun1-84.userapi.com/s/v1/ig2/F4YHwxuKFgi3QYoHCqQMjlhEGWIUmHtn_IqQUas44zgrxkPFkh7beCKwxgEkbUmtpokrkkGFaaUAFK2OnGAEgOze.jpg?quality=95&crop=0,0,1920,1920&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,1920x1920&from=bu',
#                                                                    'width': 1920},
#                                                     'owner_id': -22822305,
#                                                     'post_id': 1667676,
#                                                     'sizes': [{'height': 72,
#                                                                'type': 's',
#                                                                'url': 'https://sun1-84.userapi.com/s/v1/ig2/F4YHwxuKFgi3QYoHCqQMjlhEGWIUmHtn_IqQUas44zgrxkPFkh7beCKwxgEkbUmtpokrkkGFaaUAFK2OnGAEgOze.jpg?quality=95&crop=0,0,1920,1920&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,1920x1920&from=bu&cs=72x0',
#                                                                'width': 72},
#                                                               {'height': 160,
#                                                                'type': 'm',
#                                                                'url': 'https://sun1-84.userapi.com/s/v1/ig2/F4YHwxuKFgi3QYoHCqQMjlhEGWIUmHtn_IqQUas44zgrxkPFkh7beCKwxgEkbUmtpokrkkGFaaUAFK2OnGAEgOze.jpg?quality=95&crop=0,0,1920,1920&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,1920x1920&from=bu&cs=160x0',
#                                                                'width': 160},
#                                                               {'height': 640,
#                                                                'type': 'x',
#                                                                'url': 'https://sun1-84.userapi.com/s/v1/ig2/F4YHwxuKFgi3QYoHCqQMjlhEGWIUmHtn_IqQUas44zgrxkPFkh7beCKwxgEkbUmtpokrkkGFaaUAFK2OnGAEgOze.jpg?quality=95&crop=0,0,1920,1920&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,1920x1920&from=bu&cs=640x0',
#                                                                'width': 640},
#                                                               {'height': 1080,
#                                                                'type': 'y',
#                                                                'url': 'https://sun1-84.userapi.com/s/v1/ig2/F4YHwxuKFgi3QYoHCqQMjlhEGWIUmHtn_IqQUas44zgrxkPFkh7beCKwxgEkbUmtpokrkkGFaaUAFK2OnGAEgOze.jpg?quality=95&crop=0,0,1920,1920&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,1920x1920&from=bu&cs=1080x0',
#                                                                'width': 1080},
#                                                               {'height': 1280,
#                                                                'type': 'z',
#                                                                'url': 'https://sun1-84.userapi.com/s/v1/ig2/F4YHwxuKFgi3QYoHCqQMjlhEGWIUmHtn_IqQUas44zgrxkPFkh7beCKwxgEkbUmtpokrkkGFaaUAFK2OnGAEgOze.jpg?quality=95&crop=0,0,1920,1920&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,1920x1920&from=bu&cs=1280x0',
#                                                                'width': 1280},
#                                                               {'height': 1920,
#                                                                'type': 'w',
#                                                                'url': 'https://sun1-84.userapi.com/s/v1/ig2/F4YHwxuKFgi3QYoHCqQMjlhEGWIUmHtn_IqQUas44zgrxkPFkh7beCKwxgEkbUmtpokrkkGFaaUAFK2OnGAEgOze.jpg?quality=95&crop=0,0,1920,1920&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,1920x1920&from=bu&cs=1920x0',
#                                                                'width': 1920},
#                                                               {'height': 108,
#                                                                'type': 'o',
#                                                                'url': 'https://sun1-84.userapi.com/s/v1/ig2/F4YHwxuKFgi3QYoHCqQMjlhEGWIUmHtn_IqQUas44zgrxkPFkh7beCKwxgEkbUmtpokrkkGFaaUAFK2OnGAEgOze.jpg?quality=95&crop=0,0,1920,1920&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,1920x1920&from=bu&cs=108x0',
#                                                                'width': 108},
#                                                               {'height': 240,
#                                                                'type': 'p',
#                                                                'url': 'https://sun1-84.userapi.com/s/v1/ig2/F4YHwxuKFgi3QYoHCqQMjlhEGWIUmHtn_IqQUas44zgrxkPFkh7beCKwxgEkbUmtpokrkkGFaaUAFK2OnGAEgOze.jpg?quality=95&crop=0,0,1920,1920&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,1920x1920&from=bu&cs=240x0',
#                                                                'width': 240},
#                                                               {'height': 360,
#                                                                'type': 'q',
#                                                                'url': 'https://sun1-84.userapi.com/s/v1/ig2/F4YHwxuKFgi3QYoHCqQMjlhEGWIUmHtn_IqQUas44zgrxkPFkh7beCKwxgEkbUmtpokrkkGFaaUAFK2OnGAEgOze.jpg?quality=95&crop=0,0,1920,1920&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,1920x1920&from=bu&cs=360x0',
#                                                                'width': 360},
#                                                               {'height': 540,
#                                                                'type': 'r',
#                                                                'url': 'https://sun1-84.userapi.com/s/v1/ig2/F4YHwxuKFgi3QYoHCqQMjlhEGWIUmHtn_IqQUas44zgrxkPFkh7beCKwxgEkbUmtpokrkkGFaaUAFK2OnGAEgOze.jpg?quality=95&crop=0,0,1920,1920&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,1920x1920&from=bu&cs=540x0',
#                                                                'width': 540},
#                                                               {'height': 1920,
#                                                                'type': 'base',
#                                                                'url': 'https://sun1-84.userapi.com/s/v1/ig2/F4YHwxuKFgi3QYoHCqQMjlhEGWIUmHtn_IqQUas44zgrxkPFkh7beCKwxgEkbUmtpokrkkGFaaUAFK2OnGAEgOze.jpg?quality=95&crop=0,0,1920,1920&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,1920x1920&from=bu',
#                                                                'width': 1920}],
#                                                     'text': '',
#                                                     'user_id': 100,
#                                                     'web_view_token': 'e0a6b25147bcb90986'},
#                                           'type': 'photo'}],
#                          'comments': {'count': 531},
#                          'date': 1773559560,
#                          'edited': 1774000913,
#                          'from_id': -22822305,
#                          'hash': 'cku4WNqEYI6Ozvk9NQ',
#                          'id': 1667676,
#                          'inner_type': 'wall_wallpost',
#                          'likes': {'can_like': 0,
#                                    'count': 1127,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
# ...
#                          'comments': {'count': 316},
#                          'date': 1761222656,
#                          'from_id': -22822305,
#                          'hash': '6Kvd_BPYtgfgeS_c5w',
#                          'id': 1634960,
#                          'inner_type': 'wall_wallpost',
#                          'likes': {'can_like': 0,
#                                    'count': 329,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_type': 'post',
#                          'push_subscription': {'is_subscribed': False},
#                          'reposts': {'count': 27},
#                          'text': 'Делимся новыми деталями Фандом Феста 2025 ✨\n'
#                                  '\n'
#                                  'Программа настолько большая, что в один пост '
#                                  'не уместится. Но если коротко о главном:\n'
#                                  '\n'
#                                  '💙 Ведущими главной сцены будут рэпер BIG '
#                                  'RUSSIAN BOSS\ufeff и блогер Дима '
#                                  'Масленников, а вторым хедлайнером фестиваля '
#                                  'станет бойз-бэнд DKB\ufeff из Южной Кореи\n'
#                                  '\n'
#                                  '💙 На главной сцене выступят Импровизаторы, а '
#                                  'ещё там пройдёт конкурс косплея и K-pop '
#                                  'Cover Dance Champ\ufeff с призовым фондом '
#                                  '1,1 млн рублей\n'
#                                  '\n'
#                                  '💙 Кроме того, вас ждут паблик-токи от '
#                                  'книжных издательств, премьеры фильмов и '
#                                  'аниме, автограф-сессии и не только\n'
#                                  '\n'
#                                  'Фандом Фест пройдёт 22–23 ноября в Москве на '
#                                  'площадке Main Stage\ufeff. Больше '
#                                  'подробностей и новостей — '
#                                  '[https://vk.com/vkfandomfest|в сообществе]. '
#                                  'А билеты найдёте '
#                                  '[https://vk.com/fandomtickets|тут].',
#                          'type': 'post',
#                          'views': {'count': 885537}},
#                         {'attachments': [{'type': 'video',
#                                           'video': {'access_key': 'd512e401f640458f24',
#                                                     'can_add': 1,
#                                                     'can_dislike': 1,
#                                                     'can_like': 1,
#                                                     'can_repost': 1,
#                                                     'can_subscribe': 1,
#                                                     'comments': 316,
#                                                     'date': 1761124221,
#                                                     'description': '',
#                                                     'duration': 7,
#                                                     'first_frame_1280': 'https://iv.okcdn.ru/getVideoPreview?id=9445965630035&idx=0&type=39&tkn=BRGORvRG4PKTqs1-9ChFaHlEuPg&fn=vid_w',
#                                                     'first_frame_130': 'https://iv.okcdn.ru/getVideoPreview?id=9445965630035&idx=0&type=39&tkn=BRGORvRG4PKTqs1-9ChFaHlEuPg&fn=vid_sm',
#                                                     'first_frame_160': 'https://iv.okcdn.ru/getVideoPreview?id=9445965630035&idx=0&type=39&tkn=BRGORvRG4PKTqs1-9ChFaHlEuPg&fn=vid_d',
#                                                     'first_frame_320': 'https://iv.okcdn.ru/getVideoPreview?id=9445965630035&idx=0&type=39&tkn=BRGORvRG4PKTqs1-9ChFaHlEuPg&fn=vid_md',
#                                                     'first_frame_800': 'https://iv.okcdn.ru/getVideoPreview?id=9445965630035&idx=0&type=39&tkn=BRGORvRG4PKTqs1-9ChFaHlEuPg&fn=vid_f',
#                                                     'height': 1080,
#                                                     'id': 456244465,
#                                                     'local_views': 315912,
#                                                     'owner_id': -86529522,
#                                                     'photo_1280': 'https://iv.okcdn.ru/getVideoPreview?id=9445965630035&idx=6&type=39&tkn=D2RlyeBUqpXQhDPUnF_ikhgUtIM&fn=vid_w',
#                                                     'photo_130': 'https://iv.okcdn.ru/getVideoPreview?id=9445965630035&idx=6&type=39&tkn=D2RlyeBUqpXQhDPUnF_ikhgUtIM&fn=vid_s',
#                                                     'photo_320': 'https://iv.okcdn.ru/getVideoPreview?id=9445965630035&idx=6&type=39&tkn=D2RlyeBUqpXQhDPUnF_ikhgUtIM&fn=vid_l',
#                                                     'photo_800': 'https://iv.okcdn.ru/getVideoPreview?id=9445965630035&idx=6&type=39&tkn=D2RlyeBUqpXQhDPUnF_ikhgUtIM&fn=vid_x',
#                                                     'response_type': 'full',
#                                                     'should_stretch': False,
#                                                     'title': 'Video by VK Fest',
#                                                     'track_code': 'video_926d94f9egnSb5c4hCZ0xZuT3x64TsdGM4YWhSNDTetbd7UFOU5LI8plk1KAKnfHm_TrK45883IHsCiBVCIhh18Q-VFje3ka_1ehDUngvghWMxTUcX3zcgc',
#                                                     'tracking_info': {'navigation': {'source_block': 'no_block',
#                                                                                      'source_prev_screen': 'no_source_prev_screen',
#                                                                                      'source_screen': 'wall'},
#                                                                       'recom_info': {'feature_sampling_uuid': ''},
#                                                                       'search_info': {'search_iid': 0,
#                                                                                       'search_query_id': '0'}},
#                                                     'views': 315912,
#                                                     'width': 1080}}],
#                          'comments': {'count': 315},
#                          'coowners': {'coowner_post_id': {'owner_id': -22822305,
#                                                           'post_id': 1634847},
#                                       'is_coowner': False,
#                                       'is_owner': False,
#                                       'list': [{'can_subscribe': False,
#                                                 'is_current_user': False,
#                                                 'is_subscribed': False,
#                                                 'owner_id': -86529522},
#                                                {'can_subscribe': False,
#                                                 'is_current_user': False,
#                                                 'is_subscribed': False,
#                                                 'owner_id': -22822305}],
#                                       'requests': []},
#                          'date': 1761124323,
#                          'edited': 1761124815,
#                          'from_id': -86529522,
#                          'id': 656028,
#                          'inner_type': 'wall_wallpost',
#                          'likes': {'can_like': 0,
#                                    'count': 2216,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -86529522,
#                          'post_type': 'post',
#                          'push_subscription': {'is_subscribed': False},
#                          'reposts': {'count': 160},
#                          'text': 'Фестивальщики, общий сбор! Эксклюзивно в MAX '
#                                  'запускаем продажи early birds — билетов по '
#                                  'самой низкой цене на VK Fest 2026! \n'
#                                  '\n'
#                                  '— Фестиваль пройдёт 4 и 5 июля в '
#                                  'Санкт-Петербурге, 11 июля в Сириусе, 18 и 19 '
#                                  'июля в Москве.\n'
#                                  '— Чтобы купить, переходите в наш бот VK Fest '
#                                  'в MAX https://vk.cc/cQyc3R и забирайте '
#                                  'уникальную ссылку.\n'
#                                  '\n'
#                                  'Не расходимся! В соцсетях поделимся с вами '
#                                  'самыми свежими новостями о подготовке к VK '
#                                  'Fest 2026!',
#                          'type': 'post',
#                          'views': {'count': 177191}},
#                         {'attachments': [{'type': 'video',
#                                           'video': {'access_key': '721d120c9510b8b4db',
#                                                     'can_add': 1,
#                                                     'can_dislike': 1,
#                                                     'can_like': 1,
#                                                     'can_repost': 1,
#                                                     'can_subscribe': 1,
#                                                     'comments': 1,
#                                                     'date': 1760962990,
#                                                     'description': '',
#                                                     'duration': 15,
#                                                     'first_frame_1280': 'https://iv.okcdn.ru/getVideoPreview?id=8891957054140&idx=0&type=39&tkn=A3-t2EmyQlofJg1AvWRG8gkebPA&fn=vid_w',
#                                                     'first_frame_130': 'https://iv.okcdn.ru/getVideoPreview?id=8891957054140&idx=0&type=39&tkn=A3-t2EmyQlofJg1AvWRG8gkebPA&fn=vid_sm',
#                                                     'first_frame_160': 'https://iv.okcdn.ru/getVideoPreview?id=8891957054140&idx=0&type=39&tkn=A3-t2EmyQlofJg1AvWRG8gkebPA&fn=vid_d',
#                                                     'first_frame_320': 'https://iv.okcdn.ru/getVideoPreview?id=8891957054140&idx=0&type=39&tkn=A3-t2EmyQlofJg1AvWRG8gkebPA&fn=vid_md',
#                                                     'first_frame_800': 'https://iv.okcdn.ru/getVideoPreview?id=8891957054140&idx=0&type=39&tkn=A3-t2EmyQlofJg1AvWRG8gkebPA&fn=vid_f',
#                                                     'height': 1080,
#                                                     'id': 456243162,
#                                                     'local_views': 65787,
#                                                     'owner_id': -22822305,
#                                                     'photo_1280': 'https://iv.okcdn.ru/getVideoPreview?id=8891957054140&idx=0&type=39&tkn=A3-t2EmyQlofJg1AvWRG8gkebPA&fn=vid_w',
#                                                     'photo_130': 'https://iv.okcdn.ru/getVideoPreview?id=8891957054140&idx=0&type=39&tkn=A3-t2EmyQlofJg1AvWRG8gkebPA&fn=vid_s',
#                                                     'photo_320': 'https://iv.okcdn.ru/getVideoPreview?id=8891957054140&idx=0&type=39&tkn=A3-t2EmyQlofJg1AvWRG8gkebPA&fn=vid_l',
#                                                     'photo_800': 'https://iv.okcdn.ru/getVideoPreview?id=8891957054140&idx=0&type=39&tkn=A3-t2EmyQlofJg1AvWRG8gkebPA&fn=vid_x',
#                                                     'response_type': 'full',
#                                                     'should_stretch': False,
#                                                     'title': 'Video by '
#                                                              'ВКонтакте',
#                                                     'track_code': 'video_1d2a745555LF70RblqCh_gOKWuxHwMbulwVNCD6q_LiWD0Nwex_Ws9vtQzyVpKH6AuVe2XHy8t2mM38HScuQ1JYaGSMlS-SB6N12Y6RtbTHJKpEmjg3z3aYz',
#                                                     'tracking_info': {'navigation': {'source_block': 'no_block',
#                                                                                      'source_prev_screen': 'no_source_prev_screen',
#                                                                                      'source_screen': 'wall'},
#                                                                       'recom_info': {'feature_sampling_uuid': ''},
#                                                                       'search_info': {'search_iid': 0,
#                                                                                       'search_query_id': '0'}},
#                                                     'views': 65787,
#                                                     'width': 1080}}],
#                          'comments': {'count': 383},
#                          'date': 1760965232,
#                          'from_id': -22822305,
#                          'hash': 'kyAf1UO7H4Xg7yHhrQ',
#                          'id': 1634400,
#                          'inner_type': 'wall_wallpost',
#                          'likes': {'can_like': 0,
#                                    'count': 344,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_type': 'post',
#                          'push_subscription': {'is_subscribed': False},
#                          'reposts': {'count': 39},
#                          'text': 'Каталог подарков обновился. Теперь там есть '
#                                  'анимированные подарки! \n'
#                                  '\n'
#                                  'Встречайте: довольная жабка, хихикающие '
#                                  'крыски, мудрый волк и радостный енотик. '
#                                  'Надеемся, никого не забыли. Но вы нас лучше '
#                                  'перепроверьте, вдруг мы припрятали ещё '
#                                  'кого-то милого. \n'
#                                  '\n'
#                                  'Переходите в каталог и порадуйте друзей '
#                                  'необычным сюрпризом: vk.com/gifts/catalog',
#                          'type': 'post',
#                          'views': {'count': 180510}},
#                         {'attachments': [],
#                          'comments': {'count': 593},
#                          'date': 1760776277,
#                          'from_id': -22822305,
#                          'hash': 'wmRKLGfjBvnYz070-Q',
#                          'id': 1633714,
#                          'inner_type': 'wall_wallpost',
#                          'likes': {'can_like': 0,
#                                    'count': 510,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_type': 'post',
#                          'push_subscription': {'is_subscribed': False},
#                          'reposts': {'count': 43},
#                          'text': 'Какие сообщества ВКонтакте вы читаете чаще '
#                                  'всего?\n'
#                                  '\n'
#                                  'Мемы, новости, музыка, хобби — у каждого '
#                                  'свои любимчики! Делитесь ссылками в '
#                                  'комментариях, чтобы другие тоже открыли для '
#                                  'себя что-то классное 💙\n'
#                                  '\n'
#                                  'Скидывайте сюда, соберём топ вместе 👇',
#                          'type': 'post',
#                          'views': {'count': 303480}}]}}

# %%
len(response.json()['response']['items'])
# Out:
# 100

# %%
response.json()['response']['items'][0]
# Out:
# {'inner_type': 'wall_wallpost',
#  'comments': {'count': 292},
#  'marked_as_ads': 0,
#  'hash': 'bG9bWjsupbfFYvNgYw',
#  'type': 'post',
#  'push_subscription': {'is_subscribed': False},
#  'attachments': [{'type': 'photo',
#    'photo': {'album_id': -7,
#     'date': 1774023698,
#     'id': 457371117,
#     'owner_id': -22822305,
#     'access_key': 'a1b7a13843a5620789',
#     'post_id': 1669213,
#     'sizes': [{'height': 72,
#       'type': 's',
#       'width': 72,
#       'url': 'https://sun1-54.userapi.com/s/v1/ig2/Z9b4pzgoele2U5UsN2lxRTtMdsjMF2afTQLiQ5sJdn8WcrHFcXWuP7zbd3Mjw5HOwRRu27RpfhTMVZmh6LdKUKUH.jpg?quality=95&crop=0,0,1920,1920&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,1920x1920&from=bu&cs=72x0'},
#      {'height': 160,
#       'type': 'm',
#       'width': 160,
#       'url': 'https://sun1-54.userapi.com/s/v1/ig2/Z9b4pzgoele2U5UsN2lxRTtMdsjMF2afTQLiQ5sJdn8WcrHFcXWuP7zbd3Mjw5HOwRRu27RpfhTMVZmh6LdKUKUH.jpg?quality=95&crop=0,0,1920,1920&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,1920x1920&from=bu&cs=160x0'},
#      {'height': 640,
#       'type': 'x',
#       'width': 640,
#       'url': 'https://sun1-54.userapi.com/s/v1/ig2/Z9b4pzgoele2U5UsN2lxRTtMdsjMF2afTQLiQ5sJdn8WcrHFcXWuP7zbd3Mjw5HOwRRu27RpfhTMVZmh6LdKUKUH.jpg?quality=95&crop=0,0,1920,1920&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,1920x1920&from=bu&cs=640x0'},
#      {'height': 1080,
#       'type': 'y',
#       'width': 1080,
#       'url': 'https://sun1-54.userapi.com/s/v1/ig2/Z9b4pzgoele2U5UsN2lxRTtMdsjMF2afTQLiQ5sJdn8WcrHFcXWuP7zbd3Mjw5HOwRRu27RpfhTMVZmh6LdKUKUH.jpg?quality=95&crop=0,0,1920,1920&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,1920x1920&from=bu&cs=1080x0'},
#      {'height': 1280,
#       'type': 'z',
#       'width': 1280,
#       'url': 'https://sun1-54.userapi.com/s/v1/ig2/Z9b4pzgoele2U5UsN2lxRTtMdsjMF2afTQLiQ5sJdn8WcrHFcXWuP7zbd3Mjw5HOwRRu27RpfhTMVZmh6LdKUKUH.jpg?quality=95&crop=0,0,1920,1920&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,1920x1920&from=bu&cs=1280x0'},
#      {'height': 1920,
#       'type': 'w',
#       'width': 1920,
#       'url': 'https://sun1-54.userapi.com/s/v1/ig2/Z9b4pzgoele2U5UsN2lxRTtMdsjMF2afTQLiQ5sJdn8WcrHFcXWuP7zbd3Mjw5HOwRRu27RpfhTMVZmh6LdKUKUH.jpg?quality=95&crop=0,0,1920,1920&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,1920x1920&from=bu&cs=1920x0'},
#      {'height': 108,
#       'type': 'o',
#       'width': 108,
#       'url': 'https://sun1-54.userapi.com/s/v1/ig2/Z9b4pzgoele2U5UsN2lxRTtMdsjMF2afTQLiQ5sJdn8WcrHFcXWuP7zbd3Mjw5HOwRRu27RpfhTMVZmh6LdKUKUH.jpg?quality=95&crop=0,0,1920,1920&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,1920x1920&from=bu&cs=108x0'},
#      {'height': 240,
#       'type': 'p',
#       'width': 240,
#       'url': 'https://sun1-54.userapi.com/s/v1/ig2/Z9b4pzgoele2U5UsN2lxRTtMdsjMF2afTQLiQ5sJdn8WcrHFcXWuP7zbd3Mjw5HOwRRu27RpfhTMVZmh6LdKUKUH.jpg?quality=95&crop=0,0,1920,1920&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,1920x1920&from=bu&cs=240x0'},
#      {'height': 360,
#       'type': 'q',
#       'width': 360,
#       'url': 'https://sun1-54.userapi.com/s/v1/ig2/Z9b4pzgoele2U5UsN2lxRTtMdsjMF2afTQLiQ5sJdn8WcrHFcXWuP7zbd3Mjw5HOwRRu27RpfhTMVZmh6LdKUKUH.jpg?quality=95&crop=0,0,1920,1920&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,1920x1920&from=bu&cs=360x0'},
#      {'height': 540,
#       'type': 'r',
#       'width': 540,
#       'url': 'https://sun1-54.userapi.com/s/v1/ig2/Z9b4pzgoele2U5UsN2lxRTtMdsjMF2afTQLiQ5sJdn8WcrHFcXWuP7zbd3Mjw5HOwRRu27RpfhTMVZmh6LdKUKUH.jpg?quality=95&crop=0,0,1920,1920&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,1920x1920&from=bu&cs=540x0'},
#      {'height': 1920,
#       'type': 'base',
#       'width': 1920,
#       'url': 'https://sun1-54.userapi.com/s/v1/ig2/Z9b4pzgoele2U5UsN2lxRTtMdsjMF2afTQLiQ5sJdn8WcrHFcXWuP7zbd3Mjw5HOwRRu27RpfhTMVZmh6LdKUKUH.jpg?quality=95&crop=0,0,1920,1920&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,1920x1920&from=bu'}],
#     'text': '',
#     'user_id': 100,
#     'web_view_token': 'e9b825b5e1383c9098',
#     'orig_photo': {'height': 1920,
#      'type': 'base',
#      'url': 'https://sun1-54.userapi.com/s/v1/ig2/Z9b4pzgoele2U5UsN2lxRTtMdsjMF2afTQLiQ5sJdn8WcrHFcXWuP7zbd3Mjw5HOwRRu27RpfhTMVZmh6LdKUKUH.jpg?quality=95&crop=0,0,1920,1920&as=32x32,48x48,72x72,108x108,160x160,240x240,360x360,480x480,540x540,640x640,720x720,1080x1080,1280x1280,1440x1440,1920x1920&from=bu',
#      'width': 1920}}}],
#  'date': 1774081260,
#  'from_id': -22822305,
#  'id': 1669315,
#  'likes': {'can_like': 0, 'count': 188, 'user_likes': 0},
#  'owner_id': -22822305,
#  'post_type': 'post',
#  'reposts': {'count': 22},
#  'text': 'Играем! Угадаете персонажа по vmoji? Ждём ваши варианты в комментариях! И кидайте своих персонажей — заценим образы 💫\n\nА в мемном наборе вас ждут два новых стикера: vk.com/stickers/vmoji_meme',
#  'views': {'count': 83274}}

# %%
stats = {} 
count_post = 0 # Счётчик «непустых» сообщений
for record in response.json()['response']['items'][:]:
    title = record['text'][:30] 
    if title: 
        stats[title] = [record['comments']['count'], record['likes']['count'], record['reposts']['count'], record['date']] 
        count_post += 1 
    if count_post < 10: 
        continue 
    else: 
        break 
pprint(stats)
# Out:
# {'8 Марта уже завтра 🩷\n\nВаших бл': [174, 497, 65, 1772878800],
#  'В VK Шагах — последний и очень': [50, 239, 21, 1772868600],
#  'Если вы ещё не знакомы, знаком': [125, 751, 85, 1773846032],
#  'Если партнёр досмотрит сериал ': [322, 273, 62, 1773667444],
#  'Играем! Угадаете персонажа по ': [292, 188, 22, 1774081260],
#  'Какой стикер чаще всего отправ': [531, 1127, 44, 1773559560],
#  'Мм, ага, вот и новый розыгрыш ': [348, 926, 90, 1773308726],
#  'План на март: классно проводит': [423, 487, 34, 1772953201],
#  'Попробуем договориться с погод': [1694, 323, 36, 1772808642],
#  '💙 Синее сердечко нельзя исполь': [416, 447, 98, 1773906688]}
